# %% [markdown]
# # Lesson 2: Priority Bank Project - Bringing It All Together
#
# **Goal:** Create the buildilding blocks of a simple savings app that combines the Python basics you learned into a real project.
#
# **What is Priority Bank?** It's an app that helps girls manage their savings goals. Users can have multiple savings goals and move money between them. For example, you might have goals for a new laptop, a trip, and saving to study abroad.
#
# **In this lesson**, you'll build the core logic for Priority Bank.
#
# **Tips:**
# - These exercises get progressively harder — start at the top and work your way down
# - Each exercise builds on what you learn in the ones before
# - Feel free to test your code by changing values and running it again!

# %% [markdown]
# ## Part 1: Create a Simple Savings Goal
#
# Start by building a single goal.

# %% [markdown]
# ### Exercise 1: Goal Dictionary
#
# Create a dictionary to represent one savings goal. It should have:
# - `id`: a number like 1
# - `title`: the name of the goal (like "New Laptop")
# - `target_amount`: how much money you want to save (like 1200)
# - `saved_amount`: how much you've saved so far (like 450)
#
# Print the dictionary and then print the goal's title and how much more you need to save.

# %%
# Try it here

# %% [markdown]
# ## Part 2: Create a List of Goals
#
# Now manage multiple goals.

# %% [markdown]
# ### Exercise 2: Multiple Goals
#
# Create a list containing 3 different savings goals (as dictionaries). Each goal should have `id`, `title`, `target_amount`, and `saved_amount`.
#
# Then:
# 1. Print all the goals
# 2. Print just the titles of all goals
# 3. Print the first goal's details
#
# Hint: You'll need nested loops or accessing list items by index.

# %%
# Try it here

# %% [markdown]
# ## Part 3: Add Functions to Your Bank
#
# Create functions that do things with your goals.

# %% [markdown]
# ### Exercise 3: Add Funds Function
#
# Create a function called `add_funds()` that:
# - Takes a goal dictionary and an amount as inputs
# - Adds that amount to the goal's `saved_amount`
# - Returns the updated goal dictionary
#
# Then create a goal, call your function to add 250 euros to it, and print the result.

# %%
# Try it here

# %% [markdown]
# ### Exercise 4: Calculate Remaining Amount
#
# Create a function called `remaining_amount()` that:
# - Takes a goal dictionary as input
# - Returns how much more money needs to be saved
#
# Test it with a goal where `target_amount` is 1000 and `saved_amount` is 650.
