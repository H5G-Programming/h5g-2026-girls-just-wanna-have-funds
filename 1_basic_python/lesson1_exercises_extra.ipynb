# %% [markdown]
# # Lesson 1: Python Basics - Extra Exercises
#
# **Goal:** Strengthen your Python fundamentals with more challenging exercises.
#
# **Tips:**
# - Try to solve each exercise without looking back at the lesson (but you can!)
# - Experiment and change values to understand what's happening
# - These exercises are themed around money, savings, and goals — topics you'll use in real life and in next weeks project!
# - Ask for help if you get stuck!

# %% [markdown]
# ## 2) Variables and Types
#
# Variables store information. Python figures out what *type* of information it is automatically.

# %% [markdown]
# ### Exercise 1: Create Your Savings Profile
# Create variables for a person's name, age, savings amount, and whether they've reached their goal. Print them all together.
#
# Hint: You should have 4 variables with different types.

# %%
# Try it here

# %% [markdown]
# ### Exercise 2: Check the Types
# Create variables for: a bank account balance (like 250.50), a PIN code (1234), the bank name ("GirlBank"), and whether the account is verified (True/False). Use `type()` to check what type each one is.

# %%
# Try it here

# %% [markdown]
# ### Exercise 3: Money Math
# Create a variable for your starting savings (500), add some money you earned (125), and store the result in a new variable. Print both the starting amount and the new total.

# %%
# Try it here

# %% [markdown]
# ### Exercise 4: Goal Tracking
# Create variables for your savings goal (like "new laptop"), the target amount (1200), the current amount saved (800), and calculate how much more you need. Print a message showing all this information.

# %%
# Try it here

# %% [markdown]
# ## 3) Strings
#
# Strings are text. You can combine them with `+` to create messages.

# %% [markdown]
# ### Exercise 1: Welcome Message
# Create a variable for someone's name and create a welcome message that combines their name with text. For example: "Welcome to GirlBank, Maya!"

# %%
# Try it here

# %% [markdown]
# ### Exercise 2: Savings Report
# Create variables for a goal name, saved amount, and target amount. Combine them into a sentence like: "You have saved 500 euros toward your Hawaii trip goal (target: 2000)."

# %%
# Try it here

# %% [markdown]
# ### Exercise 3: Multi-line Statement
# Create variables for a person's name, their favorite savings app, and the amount they've saved this month. Build a sentence that includes all three, like: "Maya uses GirlBank and has saved 75 euros this month."

# %%
# Try it here

# %% [markdown]
# ### Exercise 4: Transaction Description
# Create variables for a transaction type ("transfer"), an amount (150), and a recipient ("birthday fund"). Combine them into a sentence like: "You made a transfer of 150 euros to your birthday fund."

# %%
# Try it here

# %% [markdown]
# ## 4) Lists
#
# Lists store multiple items in order. Access them by index (starting at 0).

# %% [markdown]
# ### Exercise 1: Savings Goals List
# Create a list of 5 things you want to save money for. Print the first item, the third item, and the last item.

# %%
# Try it here

# %% [markdown]
# ### Exercise 2: Add and Remove from Savings
# Create a list of bank accounts (like ["Checking", "Savings", "Emergency"]). Add a new account called "College Fund". Print the updated list.

# %%
# Try it here

# %% [markdown]
# ### Exercise 3: Monthly Expenses
# Create a list of your monthly expenses (like [50, 30, 100, 75]). Print:
# - The first expense
# - The last expense
# - Add a new expense of 25
# - Print the updated list

# %%
# Try it here

# %% [markdown]
# ### Exercise 4: Transaction History
# Create a list of recent transactions (like ["earned money", "bought book", "saved", "bought coffee", "gift from grandma"]). Print the middle transaction. Then add a new transaction. Print the entire updated list.

# %%
# Try it here

# %% [markdown]
# ## 5) Dictionaries
#
# Dictionaries store information as key-value pairs, like a real dictionary where you look up a word (key) to find its meaning (value).

# %% [markdown]
# ### Exercise 1: Bank Account Info
# Create a dictionary for a bank account with keys: `account_number`, `holder_name`, `balance`, and `account_type`. Print the balance.

# %%
# Try it here

# %% [markdown]
# ### Exercise 2: Savings Goal Dictionary
# Create a dictionary for a savings goal with keys: `goal_name`, `target_amount`, `current_amount`, and `deadline`. Print each piece of information by accessing the keys.

# %%
# Try it here

# %% [markdown]
# ### Exercise 3: Add New Information
# Create a dictionary for a person with keys: `name`, `age`, and `favorite_color`. Add a new key `monthly_savings` with a value. Then print the entire dictionary.

# %%
# Try it here

# %% [markdown]
# ### Exercise 4: Update Account Info
# Create a dictionary for a bank account with `account_type`, `balance`, and `last_transaction`. Update the balance (add 200 to it) and update the last_transaction to "deposited 200". Print the updated dictionary.

# %%
# Try it here

# %% [markdown]
# ## 6) If Statements
#
# Use `if`, `elif`, and `else` to make your program do different things based on conditions.

# %% [markdown]
# ### Exercise 1: Savings Milestone
# Create a variable for the amount saved (like 500). Use an if/elif/else statement to print:
# - "You've reached your goal!" if saved >= 1000
# - "You're halfway there!" if saved >= 500
# - "Keep saving!" otherwise

# %%
# Try it here

# %% [markdown]
# ### Exercise 2: Age-Based Account Type
# Create a variable for someone's age. Use if/elif/else to print:
# - "Teen account" if age < 18
# - "Young adult account" if age < 25
# - "Adult account" otherwise
