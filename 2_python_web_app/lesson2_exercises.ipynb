# %% [markdown]
# # Lesson 2: Making Priority Bank Work
#
# In this lesson, you will write the actual code that makes Priority Bank do things.
# The app has 5 exercises — your job is to complete them, one at a time.
# > 👯 **Work in pairs!** One person types (the **Driver**), the other guides (the **Navigator**). Switch roles after each exercise.
#
# ## How each exercise works:
# 1. Read the explanation and the concept
# 2. Run the _mini-example_ in the cell below — it shows the idea using simple examples
# 3. Follow the instructions to write the real code in `app_needs_help.py`
# 4. Test it in the app!
#
#
# ### Exercises
# 1. Link to the real app - change the user name to your own
# 2. Add funds to a goal - the money is not added to the goal
# 3. Creating a goal - the goal is not added to the list of goals
# 4. Move funds - the money is not moved from one goal to another
# 5. Closing goal - the money in the closed goal is not moved to another goal
#
# ### How can you make sure your changes work?
# 1. Run the notebook mini-examples — each should print the expected before/after output.
# 2. After you've filled in each exercise, open app and test the corresponding button in the Priority Bank UI:
#     - Ex 1: See you name in the top of the website
#     - Ex 2: Click "Add funds" on an existing goal → saved amount goes up.
#     - Ex 3: Click "Add goal" → new goal appears on the dashboard.
#     - Ex 4: Click "Move funds" → money moves between two goals.
#     - Ex 5: Click "Close goal" → remaining funds move to chosen goal, closed goal disappears.
# 3. The complete app (all 4 exercises done) should match the behaviour of the original `app.py`.

# %% [markdown]
# ---
# ## Exercise 1: Link to the Real App
#
# **Concept:** Changing a value inside a dictionary.
#
# In `backend/app_needs_help.py` there is a dictionary called `user` that looks like this:
#
# ```python
# user = {"id": 1, "name": "Maya"}
# ```
#
# The `/api/user` endpoint returns this dictionary as JSON. If you change the `name`, the app will greet you instead of Maya.
#
# Run the mini-example below to see how changing a dictionary value works:

# %%
# Mini-example: Changing a value in a dictionary
user = {"id": 1, "name": "Maya"}
print("Before:", user)

user["name"] = "Naomi"

print("After: ", user)
# Out:
# Before: {'id': 1, 'name': 'Maya'}
# After:  {'id': 1, 'name': 'Naomi'}

# %% [markdown]
# ### Challenge
#
# 1. Open `backend/app_needs_help.py`
# 2. Find the dictionary called `user` near the top of the file (line 10)
# 3. Change `"Maya"` to your own name
# 4. Save the file and check the app (`python3 app.py`), and check the app
#
# Does your name show up? You did it! ✨

# %% [markdown]
# ---
# ## Exercise 2: Add Funds
#
# **Concept:** Accessing and updating a value inside a dictionary.
#
# In Priority Bank, there are no bank accounts — only **goals**. When you add money, you choose which goal it goes towards.
# The goal is a dictionary, and the money saved is stored in a key called `saved_amount`.
#
# Your job: update `saved_amount` by adding the new `amount` to it.
#
# Run the mini-example below first to see how it works:

# %%
# Mini-example: Adding money to a savings dictionary
savings = {"amount": 100}
print("Before:", savings)

savings["amount"] = savings["amount"] + 50

print("After: ", savings)

# %% [markdown]
# ### Now do it for real
#
# 1. Open `backend/app_needs_help.py`
# 2. Find the function called `add_funds` (search for `EXERCISE 2`)
# 3. You'll see a line with a blank (`_____`) — fill in the blank to make it work! Write a line that adds `amount` to `goal["saved_amount"]`
# 4. Save the file and check the app (`python3 app_needs_help.py`), and click **Add funds** on a goal in the app.
#
# Did the saved amount go up? You did it! ✨

# %%
goal["saved_amount"] = _____ + amount

# %% [markdown]
# 💡 **Hint:** What is the current saved amount? How do you access it?

# %% [markdown]
# ---
# ## Exercise 3: Create a Goal
#
# **Concept:** Creating a dictionary and adding it to a list.
#
# Remember from Lesson 1: dictionaries store key-value pairs, and lists can hold multiple dictionaries.
# Each goal in Priority Bank is a dictionary inside a list called `goals`.
#
# Your job: build a new goal dictionary and add it to the list.
#
# Run the mini-example below first:

# %%
# Mini-example: Creating a goal and adding it to a list
goals = []

new_goal = {"title": "New sneakers", "target": 200, "saved": 0}

goals.append(new_goal)

print("Goals list:", goals)

# %% [markdown]
# ### Now do it for real
#
# 1. Open `backend/app_needs_help.py`
# 2. Find the function called `create_goal` (search for `EXERCISE 3`)
# 3. You'll see a dictionary that's been started for you — but it's not finished! Complete it by adding the remaining keys.
# 4. After completing the dictionary, add `new_goal` to the `goals` list (hint: which list method adds an item to the end?)
# 5. Save the file and check the app, and click **Add goal** in the app.
#
# Does your new goal show up on the dashboard? ✨

# %%
new_goal = {
    "id": next_goal_id,
    "title": title,
    # Add the remaining keys yourself:
    # target_amount, saved_amount, emoji, image_url, status
    # Hint: saved_amount starts at 0, status should be "active"
}

# Add new_goal to the goals list below:

# %% [markdown]
# ---
# ## Exercise 4: Move Funds
#
# **Concept:** Updating two dictionaries at the same time using `+` and `-`.
#
# Sometimes you save up for one thing but then change your mind and want the money to go somewhere else.
# Moving funds means: subtract from one goal, add to another.
#
# This is like Exercise 2 — but now you have two goals instead of one!
#
# Run the mini-example below first:

# %%
# Mini-example: Moving money between two goals
sneakers = {"title": "Sneakers", "saved": 100}
art_set  = {"title": "Art set",   "saved": 30}

amount = 25  # we want to move 25 from sneakers to art_set

sneakers["saved"] = sneakers["saved"] - amount
art_set["saved"]  = art_set["saved"]  + amount

print("Sneakers:", sneakers)
print("Art set: ", art_set)

# %% [markdown]
# ### Now do it for real
#
# 1. Open `backend/app_needs_help.py`
# 2. Find the function called `move_funds` (search for `EXERCISE 4`)
# 3. You'll see a comment showing the pattern from the mini-example. Use it to write two lines!
# 4. Save the file and check the app, and try moving funds between two goals in the app.
#
# Does the money move from one goal to the other? ✨

# %%
# Pattern from the mini-example:
#   something["saved"] = something["saved"] - amount
# Now do it with source_goal and target_goal using "saved_amount":

# %% [markdown]
# ---
# ## Exercise 5: Close a Goal
#
# **Concept:** Using an `if` statement to conditionally move money before closing a goal.
#
# When you close a goal, any money you had saved towards it doesn't just disappear.
# If there's still money in it, it should move to another goal first.
# But if the goal is already empty (saved amount is 0), there's nothing to move.
#
# That's where an `if` statement comes in — it only runs code when a condition is true.
#
# Run the mini-example below first:

# %%
# Mini-example: Closing a goal and moving leftover funds
goal_closing = {"title": "Concert ticket", "saved": 40, "status": "active"}
goal_target  = {"title": "Sneakers",       "saved": 100}

amount = goal_closing["saved"]  # how much is left in the goal?

if amount > 0:  # only move money if there IS money to move
    goal_closing["saved"] = 0
    goal_target["saved"]  = goal_target["saved"] + amount

goal_closing["status"] = "closed"  # mark the goal as closed

print("Closed goal:", goal_closing)
print("Target goal:", goal_target)

# %% [markdown]
# ### Now do it for real
#
# 1. Open `backend/app_needs_help.py`
# 2. Find the function called `close_goal` (search for `EXERCISE 5`)
# 3. There are 3 spots to fill in — try each one below first, then write it in the file!
#
# Try it yourself first, then click the hint if you get stuck. ✨

# %%
# (1 of 3) Store the saved amount in a variable called amount

# %% [markdown]
# <details>
# <summary>🔍 Stuck? Click here for a hint</summary>
#
# Look at the mini-example above — the line `amount = goal_closing["saved"]` does exactly this.
# In your code, the goal is called `goal_to_be_closed` and the key is `"saved_amount"`.
#
# </details>

# %%
# (2 of 3) If amount > 0, move funds to target_goal and set goal_to_be_closed's saved_amount to 0

# %% [markdown]
# <details>
# <summary>🔍 Stuck? Click here for a hint</summary>
#
# From the mini-example:
# ```python
# if amount > 0:
#     goal_closing["saved"] = 0
#     goal_target["saved"] = goal_target["saved"] + amount
# ```
# Your variables are called `goal_to_be_closed` and `target_goal`, and the key is `"saved_amount"`.
#
# </details>

# %%
# (3 of 3) Set the status of goal_to_be_closed to "closed"

# %% [markdown]
# <details>
# <summary>🔍 Stuck? Click here for a hint</summary>
#
# From the mini-example: `goal_closing["status"] = "closed"`.
# Your variable is called `goal_to_be_closed`.
#
# </details>

# %% [markdown]
# ---
# ## Bonus: Read the code
#
# Finished all 5 exercises? Well done!
#
# There is one more feature in the app: **Complete Goal**. The code for this is already written in `app_needs_help.py`.
# Find the function called `complete_goal` and read through it.
#
# **Challenge:** Can you predict what happens in the app when you click "Complete Goal" on a goal?
# Try it out and see if you were right!
