# %% [markdown]
# # 🔁 Lesson 2 – Repetition & Mini Priority Bank
#
# Work in pairs!
#
# ---
#
# ## Part 1: Quick warm-up
# Let's go through what we learned last time.

# %% [markdown]
# ### Exercise 1 – Variables & types
#
# Create the following variables:
# - `name` – your name (string)
# - `age` – your age (int)
# - `savings` – how much you've saved up (float)
# - `has_goal` – whether you have a savings goal (bool)
#
# Print all four variables and their types using `type()`.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 2 – String magic ✨
#
# Use your variables from exercise 1 to print this sentence using `+`:
#
# ```
# Hi, my name is Maya and I am 15 years old!
# ```
#
# 💡 **Hint:** Use `str()` to convert numbers to text, e.g. `str(age)`

# %%
# Your code here:

# %% [markdown]
# ### Exercise 3 – Lists & index
#
# a) Create a list `goals` with 3 things you'd like to save up for.
#
# b) Print the **first** element.
#
# c) Print the **last** element (hint: you can use `[-1]`).
#
# d) Add a new goal using `.append()` and print the full list.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 4 – Dictionary
#
# Create a dictionary `goal_1` with these keys:
# - `"name"` – the name of your savings goal
# - `"target"` – how much you need (e.g. 5000)
# - `"saved"` – how much you've saved so far (e.g. 1200)
#
# Print the name of your goal and how much you still need (target minus saved).

# %%
# Your code here:

# %% [markdown]
# ### Exercise 5 – If-statement + loop
#
# Here's a list of amounts:
#
# ```python
# amounts = [200, 750, 1500, 50, 3000, 400]
# ```
#
# Use a **for-loop** and an **if-statement** to print:
# - `"💰 Big amount: X"` if the amount is 1000 or more
# - `"🪙 Small amount: X"` if the amount is less than 1000

# %%
amounts = [200, 750, 1500, 50, 3000, 400]

# Your code here:

# %% [markdown]
# ---
#
# ## Part 2: 🏦 Mini Priority Bank
#
# Now we combine everything! You'll build a small "Priority Bank" that keeps track of savings goals.
#
# Work through the exercises – they build on each other.

# %% [markdown]
# ### Exercise 6 – Create a user
#
# Create a dictionary `user` with:
# - `"name"` – a name
# - `"balance"` – how much money the user has in total (e.g. 8000)
# - `"goals"` – an **empty list** `[]` (we'll add goals later)

# %%
# Your code here:

# %% [markdown]
# ### Exercise 7 – Add savings goals
#
# Create **3 dictionaries** – one for each savings goal. Each goal should have:
# - `"name"` – e.g. `"Hawaii trip"`
# - `"target"` – e.g. `3000`
# - `"saved"` – e.g. `500`
#
# Add them to the user's `goals` list using `.append()`.
#
# Print `user` and check that the list now has 3 goals.

# %%
# Example of one goal:
goal_a = {"name": "Hawaii trip", "target": 3000, "saved": 500}

# Create two more and add all three to user["goals"]:

# %% [markdown]
# ### Exercise 8 – Display all goals with a loop
#
# Use a **for-loop** to print each goal nicely. For each goal, print:
#
# ```
# 🎯 Hawaii trip: 500 / 3000 kr
# ```
#
# 💡 **Hint:** You can access values from a dictionary inside the loop:
# ```python
# for goal in user["goals"]:
#     print(goal["name"])
# ```

# %%
# Your code here:

# %% [markdown]
# ### Exercise 9 – Check status with if-statements
#
# Extend your loop: for each goal, check how far the user has come:
#
# - If `saved >= target` → print `"✅ Goal reached!"`
# - If `saved >= target / 2` → print `"🔥 More than halfway!"`
# - Otherwise → print `"💪 Keep going!"`
#
# Test it by changing the `saved` values in your goals so you see all three messages.

# %%
# Your code here:

# %% [markdown]
# ### Exercise 10 – Full overview 📊
#
# Print a full overview of the user:
#
# ```
# === Priority Bank ===
# User: Maya
# Balance: 8000 kr
# Number of goals: 3
#
# 🎯 Hawaii trip: 500 / 3000 kr – 💪 Keep going!
# 🎯 New laptop: 2000 / 3500 kr – 🔥 More than halfway!
# 🎯 Gift for mom: 300 / 300 kr – ✅ Goal reached!
#
# Total saved: 2800 kr
# Total remaining: 3500 kr
# ```
#
# 💡 **Hints:**
# - Use a variable `total_saved = 0` and add to it inside the loop
# - Use `len(user["goals"])` to find the number of goals

# %%
# Your code here:

# %% [markdown]
# ---
#
# ### 🌟 Bonus – Deposit money
#
# Write code that:
# 1. Picks the **first** goal in the list
# 2. Adds 500 kr to its `"saved"` value
# 3. Subtracts 500 kr from the user's `"balance"`
# 4. Prints a message: `"Deposited 500 kr to Hawaii trip!"`
# 5. Prints the new balance and the new saved amount
#
# 💡 **Hint:** `user["goals"][0]` gives you the first goal.

# %%
# Your code here:

# %% [markdown]
# ---
#
# ## 🎉 Nice work!
#
# You've now built a mini Priority Bank using:
# - Variables & types
# - Strings
# - Lists
# - Dictionaries
# - If-statements
# - For-loops
#
# **Next up: we'll all meet and learn about functions** – this will let us package code like exercise 10 into reusable pieces!
